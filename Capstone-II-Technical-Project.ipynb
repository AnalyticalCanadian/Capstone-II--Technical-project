# %% [markdown]
# ## Flight Fare Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
Train_data = pd.read_csv('./Team_pred.csv')
# Out:
# C:\Users\91968\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ## Train Data

# %%
Train_data
# Out:
#        Total_Stops  Price  Journey_day  Journey_month  Dep_hour  Dep_min  \
# 0                0   3897           24              3        22       20
# 1                2   7662            1              5         5       50
# 2                2  13882            9              6         9       25
# 3                1   6218           12              5        18        5
# 4                1  13302            1              3        16       50
# ...            ...    ...          ...            ...       ...      ...
# 10677            0   4107            9              4        19       55
# 10678            0   4145           27              4        20       45
# 10679            0   7229           27              4         8       20
# 10680            0  12648            1              3        11       30
# 10681            2  11753            9              5        10       55
#
#        Arrival_hour  Arrival_min  Duration_hours  Duration_mins  ...  \
# ...

# %%
Train_data.shape
# Out:
# (10682, 30)

# %%
Train_data.describe()
# Out:
#         Total_Stops         Price   Journey_day  Journey_month      Dep_hour  \
# count  10682.000000  10682.000000  10682.000000   10682.000000  10682.000000
# mean       0.824190   9087.214567     13.509081       4.708575     12.491013
# std        0.675229   4611.548810      8.479363       1.164408      5.748820
# min        0.000000   1759.000000      1.000000       3.000000      0.000000
# 25%        0.000000   5277.000000      6.000000       3.000000      8.000000
# 50%        1.000000   8372.000000     12.000000       5.000000     11.000000
# 75%        1.000000  12373.000000     21.000000       6.000000     18.000000
# max        4.000000  79512.000000     27.000000       6.000000     23.000000
#
#             Dep_min  Arrival_hour   Arrival_min  Duration_hours  \
# count  10682.000000  10682.000000  10682.000000    10682.000000
# mean      24.409287     13.349186     24.690601       10.244898
# std       18.767801      6.859317     16.506808        8.494916
# ...

# %%
Train_data.isna().sum()
# Out:
# Total_Stops                                  0
# Price                                        0
# Journey_day                                  0
# Journey_month                                0
# Dep_hour                                     0
# Dep_min                                      0
# Arrival_hour                                 0
# Arrival_min                                  0
# Duration_hours                               0
# Duration_mins                                0
# Airline_Air India                            0
# Airline_GoAir                                0
# Airline_IndiGo                               0
# Airline_Jet Airways                          0
# Airline_Jet Airways Business                 0
# Airline_Multiple carriers                    0
# Airline_Multiple carriers Premium economy    0
# Airline_SpiceJet                             0
# Airline_Trujet                               0
# Airline_Vistara                              0
# ...

# %% [markdown]
# ## Test set

# %%
Test_data = pd.read_csv('./Test_data.csv')

# %%
Test_data
# Out:
#       Total_Stops  Journey_day  Journey_month  Dep_hour  Dep_min  \
# 0               1            6              6        17       30
# 1               1           12              5         6       20
# 2               1           21              5        19       15
# 3               1           21              5         8        0
# 4               0           24              6        23       55
# ...           ...          ...            ...       ...      ...
# 2666            1            6              6        20       30
# 2667            0           27              3        14       20
# 2668            1            6              3        21       50
# 2669            1            6              3         4        0
# 2670            1           15              6         4       55
#
#       Arrival_hour  Arrival_min  Duration_hours  Duration_mins  Air India  \
# 0                4           25              10             55      False
# ...

# %%
Test_data.shape
# Out:
# (2671, 28)

# %%
Test_data.isna().sum()
# Out:
# Total_Stops                          0
# Journey_day                          0
# Journey_month                        0
# Dep_hour                             0
# Dep_min                              0
# Arrival_hour                         0
# Arrival_min                          0
# Duration_hours                       0
# Duration_mins                        0
# Air India                            0
# GoAir                                0
# IndiGo                               0
# Jet Airways                          0
# Jet Airways Business                 0
# Multiple carriers                    0
# Multiple carriers Premium economy    0
# SpiceJet                             0
# Vistara                              0
# Vistara Premium economy              0
# Chennai                              0
# Delhi                                0
# Kolkata                              0
# Mumbai                               0
# Cochin                               0
# ...

# %% [markdown]
#  ## Feature Selection ( Independent Variables & Dependent Variable)

# %%
X = Train_data.loc[:, ['Total_Stops', 'Journey_day', 'Journey_month', 'Dep_hour',
       'Dep_min', 'Arrival_hour', 'Arrival_min', 'Duration_hours',
       'Duration_mins', 'Airline_Air India', 'Airline_GoAir', 'Airline_IndiGo',
       'Airline_Jet Airways', 'Airline_Jet Airways Business',
       'Airline_Multiple carriers',
       'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
       'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy',
       'Source_Chennai', 'Source_Delhi', 'Source_Kolkata', 'Source_Mumbai',
       'Destination_Cochin', 'Destination_Delhi', 'Destination_Hyderabad',
       'Destination_Kolkata', 'Destination_New Delhi']]
X.head()
# Out:
#    Total_Stops  Journey_day  Journey_month  Dep_hour  Dep_min  Arrival_hour  \
# 0            0           24              3        22       20             1
# 1            2            1              5         5       50            13
# 2            2            9              6         9       25             4
# 3            1           12              5        18        5            23
# 4            1            1              3        16       50            21
#
#    Arrival_min  Duration_hours  Duration_mins  Airline_Air India  ...  \
# 0           10               2             50              False  ...
# 1           15               7             25               True  ...
# 2           25              19              0              False  ...
# 3           30               5             25              False  ...
# 4           35               4             45              False  ...
#
#    Airline_Vistara Premium economy  Source_Chennai  Source_Delhi  \
# ...

# %%
y = Train_data.iloc[:, 1]
y.head()
# Out:
# 0     3897
# 1     7662
# 2    13882
# 3     6218
# 4    13302
# Name: Price, dtype: int64

# %%
# Finds correlation between Independent and dependent attributes

plt.figure(figsize=(12, 10))  # Adjust the figure size to fit better
sns.heatmap(Test_data.corr(), annot=True, cmap="RdYlGn", annot_kws={"size": 7}, fmt=".2f", linewidths=.5)
plt.xticks(rotation=45)  # Rotate the x-axis labels for better visibility
plt.yticks(rotation=0)  # Rotate the y-axis labels for better visibility
plt.show()

# %% [markdown]
# # Important Feature using ExtraTressRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
selection = ExtraTreesRegressor()
selection.fit(X, y)
# Out:
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [2.20052139e-01 1.44181676e-01 5.34855418e-02 2.38540995e-02
#  2.14078722e-02 2.75957124e-02 1.92205111e-02 1.35357347e-01
#  1.74886460e-02 9.66132161e-03 1.71549441e-03 1.67709375e-02
#  1.38055651e-01 6.71590122e-02 1.87510464e-02 8.22227841e-04
#  2.98660794e-03 1.14075361e-04 5.19923309e-03 9.58819226e-05
#  4.49639013e-04 8.13652670e-03 3.21817716e-03 6.47330625e-03
#  1.29418496e-02 1.20300955e-02 7.59147583e-03 5.46522234e-04
#  2.46373740e-02]

# %%
#plot graph of feature importances 
plt.figure(figsize = (12,8))
feat_importances = pd.Series(selection.feature_importances_, index=X.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()
